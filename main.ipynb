# %% [markdown]
# <a href="https://colab.research.google.com/github/chad9012/DataPreprossing3SemProject/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/global-data-on-sustainable-energy (1).csv")

# %%
df.shape
# Out:
# (3649, 21)

# %%
df.sample(10)
# Out:
#           Entity  Year  Access to electricity (% of population)  \
# 1551       India  2017                                92.124950
# 1781    Kiribati  2016                                92.799614
# 1860     Lebanon  2011                                99.684010
# 2257     Myanmar  2016                                55.600000
# 3553  Uzbekistan  2009                                99.852905
# 3159       Sudan  2014                                44.900000
# 269      Bahrain  2017                               100.000000
# 1687       Japan  2006                               100.000000
# 62       Algeria  2020                                99.804130
# 3193      Sweden  2006                               100.000000
#
#       Access to clean fuels for cooking  \
# 1551                               55.8
# 1781                                6.5
# 1860                                NaN
# 2257                               21.8
# 3553                               85.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3649 entries, 0 to 3648
# Data columns (total 21 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Entity                                                            3649 non-null   object
#  1   Year                                                              3649 non-null   int64
#  2   Access to electricity (% of population)                           3639 non-null   float64
#  3   Access to clean fuels for cooking                                 3480 non-null   float64
#  4   Renewable-electricity-generating-capacity-per-capita              2718 non-null   float64
#  5   Financial flows to developing countries (US $)                    1560 non-null   float64
#  6   Renewable energy share in the total final energy consumption (%)  3455 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Entity                                                                 0
# Year                                                                   0
# Access to electricity (% of population)                               10
# Access to clean fuels for cooking                                    169
# Renewable-electricity-generating-capacity-per-capita                 931
# Financial flows to developing countries (US $)                      2089
# Renewable energy share in the total final energy consumption (%)     194
# Electricity from fossil fuels (TWh)                                   21
# Electricity from nuclear (TWh)                                       126
# Electricity from renewables (TWh)                                     21
# Low-carbon electricity (% electricity)                                42
# Primary energy consumption per capita (kWh/person)                     0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)          207
# ...

# %%
df.corr()
# Out:
# <ipython-input-137-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                                         Year  \
# Year                                                1.000000
# Access to electricity (% of population)             0.124890
# Access to clean fuels for cooking                   0.073292
# Renewable-electricity-generating-capacity-per-c...  0.104365
# Financial flows to developing countries (US $)      0.141820
# Renewable energy share in the total final energ... -0.029384
# Electricity from fossil fuels (TWh)                 0.032615
# Electricity from nuclear (TWh)                     -0.004820
# Electricity from renewables (TWh)                   0.073935
# Low-carbon electricity (% electricity)              0.030126
# ...

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# <ipython-input-138-49d8e8d45672>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# <Axes: >

# %%
#target variable = Renewable energy share in the total final energy consumption (%)

# %%
df.hist(figsize=(20, 12))
plt.suptitle('Histograms of DataFrame Columns')
plt.show()

# %%
sns.distplot(df["Year"])
# Out:
# <ipython-input-141-a4995218557c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Year"])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
sns.distplot(df["Access to electricity (% of population)"])
# Out:
# <ipython-input-142-ce201ad342ac>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Access to electricity (% of population)"])
# <Axes: xlabel='Access to electricity (% of population)', ylabel='Density'>

# %%
sns.distplot(df["Access to clean fuels for cooking"])
# Out:
# <ipython-input-143-5893f31173a8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Access to clean fuels for cooking"])
# <Axes: xlabel='Access to clean fuels for cooking', ylabel='Density'>

# %%
sns.distplot(df["Renewable-electricity-generating-capacity-per-capita"])
# Out:
# <ipython-input-144-bb07e764cc9f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Renewable-electricity-generating-capacity-per-capita"])
# <Axes: xlabel='Renewable-electricity-generating-capacity-per-capita', ylabel='Density'>

# %%
sns.distplot(df["Financial flows to developing countries (US $)"])
# Out:
# <ipython-input-145-1a557478b5ab>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Financial flows to developing countries (US $)"])
# <Axes: xlabel='Financial flows to developing countries (US $)', ylabel='Density'>

# %%
sns.distplot(df["Renewable energy share in the total final energy consumption (%)"])
# Out:
# <ipython-input-146-d6e5f3f201ed>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Renewable energy share in the total final energy consumption (%)"])
# <Axes: xlabel='Renewable energy share in the total final energy consumption (%)', ylabel='Density'>

# %%
sns.distplot(df["Electricity from fossil fuels (TWh)"])
# Out:
# <ipython-input-147-94b648d60707>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Electricity from fossil fuels (TWh)"])
# <Axes: xlabel='Electricity from fossil fuels (TWh)', ylabel='Density'>

# %%
sns.distplot(df["Electricity from nuclear (TWh)"])
# Out:
# <ipython-input-148-dccc165653fc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Electricity from nuclear (TWh)"])
# <Axes: xlabel='Electricity from nuclear (TWh)', ylabel='Density'>

# %%
sns.distplot(df["Electricity from renewables (TWh)"])
# Out:
# <ipython-input-149-c9901d6b89b9>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Electricity from renewables (TWh)"])
# <Axes: xlabel='Electricity from renewables (TWh)', ylabel='Density'>

# %%
sns.distplot(df["Low-carbon electricity (% electricity)"])
# Out:
# <ipython-input-150-bb165218998c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Low-carbon electricity (% electricity)"])
# <Axes: xlabel='Low-carbon electricity (% electricity)', ylabel='Density'>

# %%
sns.distplot(df['Primary energy consumption per capita (kWh/person)'])
# Out:
# <ipython-input-151-bb0fbec6dcc3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Primary energy consumption per capita (kWh/person)'])
# <Axes: xlabel='Primary energy consumption per capita (kWh/person)', ylabel='Density'>

# %%
sns.distplot(df['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'])
# Out:
# <ipython-input-152-7e8640212437>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Energy intensity level of primary energy (MJ/$2017 PPP GDP)'])
# <Axes: xlabel='Energy intensity level of primary energy (MJ/$2017 PPP GDP)', ylabel='Density'>

# %%
sns.distplot(df['Value_co2_emissions_kt_by_country'])
# Out:
# <ipython-input-153-c50390bc7b5c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Value_co2_emissions_kt_by_country'])
# <Axes: xlabel='Value_co2_emissions_kt_by_country', ylabel='Density'>

# %%
sns.distplot(df['Renewables (% equivalent primary energy)'])
# Out:
# <ipython-input-154-076c60d3505d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Renewables (% equivalent primary energy)'])
# <Axes: xlabel='Renewables (% equivalent primary energy)', ylabel='Density'>

# %%
sns.distplot(df['gdp_growth'])
# Out:
# <ipython-input-155-b3d824a8ab54>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['gdp_growth'])
# <Axes: xlabel='gdp_growth', ylabel='Density'>

# %%
sns.distplot(df['gdp_per_capita'])
# Out:
# <ipython-input-156-de21eb02271f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['gdp_per_capita'])
# <Axes: xlabel='gdp_per_capita', ylabel='Density'>

# %%
sns.distplot(df['Land Area(Km2)'])
# Out:
# <ipython-input-157-720a48415142>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Land Area(Km2)'])
# <Axes: xlabel='Land Area(Km2)', ylabel='Density'>

# %%
sns.distplot(df['Latitude'])
# Out:
# <ipython-input-158-c071818e7e88>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Latitude'])
# <Axes: xlabel='Latitude', ylabel='Density'>

# %%
sns.distplot(df['Longitude'])
# Out:
# <ipython-input-159-3193c8d74262>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Longitude'])
# <Axes: xlabel='Longitude', ylabel='Density'>

# %%
df.drop('Year',axis=1,inplace=True)

# %%
df.drop('Financial flows to developing countries (US $)',axis=1,inplace=True)

# %%
df.drop('Electricity from renewables (TWh)',axis=1,inplace=True)

# %%
df.drop('gdp_growth',axis=1,inplace=True)

# %%
df.drop('Land Area(Km2)',axis=1,inplace=True)

# %%
df.drop('Longitude',axis=1,inplace=True)

# %%
df.drop("Renewable-electricity-generating-capacity-per-capita",axis=1,inplace=True)

# %%
df.drop("Electricity from fossil fuels (TWh)",axis=1,inplace=True)

# %%
df.drop("Electricity from nuclear (TWh)",axis=1,inplace=True)

# %%
df.drop("Value_co2_emissions_kt_by_country",axis=1,inplace=True)

# %%
df
# Out:
#            Entity  Access to electricity (% of population)  \
# 0     Afghanistan                                 1.613591
# 1     Afghanistan                                 4.074574
# 2     Afghanistan                                 9.409158
# 3     Afghanistan                                14.738506
# 4     Afghanistan                                20.064968
# ...           ...                                      ...
# 3644     Zimbabwe                                42.561730
# 3645     Zimbabwe                                44.178635
# 3646     Zimbabwe                                45.572647
# 3647     Zimbabwe                                46.781475
# 3648     Zimbabwe                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# 3                                   9.5
# 4                                  10.9
# ...

# %%
df.shape
# Out:
# (3649, 11)

# %%
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# <ipython-input-170-407fc1d37529>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Entity                                                                 0
# Access to electricity (% of population)                               10
# Access to clean fuels for cooking                                    169
# Renewable energy share in the total final energy consumption (%)     194
# Low-carbon electricity (% electricity)                                42
# Primary energy consumption per capita (kWh/person)                     0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)          207
# Renewables (% equivalent primary energy)                            2137
# gdp_per_capita                                                       282
# Density\n(P/Km2)                                                       1
# Latitude                                                               1
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

missing_percentage_df = pd.DataFrame({'Column_Name': missing_percentage.index, 'Missing_Percentage': missing_percentage.values})

missing_percentage_df = missing_percentage_df.sort_values(by='Missing_Percentage', ascending=False)

print(missing_percentage_df)
# Out:
#                                           Column_Name  Missing_Percentage
# 7            Renewables (% equivalent primary energy)           58.563990
# 8                                      gdp_per_capita            7.728145
# 6   Energy intensity level of primary energy (MJ/$...            5.672787
# 3   Renewable energy share in the total final ener...            5.316525
# 2                   Access to clean fuels for cooking            4.631406
# 4              Low-carbon electricity (% electricity)            1.151000
# 1             Access to electricity (% of population)            0.274048
# 9                                    Density\n(P/Km2)            0.027405
# 10                                           Latitude            0.027405
# 0                                              Entity            0.000000
# 5   Primary energy consumption per capita (kWh/per...            0.000000

# %%
sns.scatterplot(x="Access to electricity (% of population)",y="Access to clean fuels for cooking",data=df)
# Out:
# <Axes: xlabel='Access to electricity (% of population)', ylabel='Access to clean fuels for cooking'>
